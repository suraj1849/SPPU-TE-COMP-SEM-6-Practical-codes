# %%
import random

def greet():
    greetings = ["Hi there!", "Hello!", "Hey!"]
    return random.choice(greetings)

def ask_name():
    return input("What's your name? ")

def chat():
    print(greet())
    name = ask_name()
    print("Nice to meet you, " + name + "!")
    while True:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            print("Bot: Goodbye!")
            break
        else:
            response = generate_response(user_input)
            print("Bot:", response)

def generate_response(user_input):
    responses = {
        "hello": "Hello! Welcome to our online store. How can I assist you today?",
        "what products do you offer?": "We offer a wide range of products including electronics, clothing, accessories, home goods, and more!",
        "do you have any sales or promotions?": "Yes, we often have sales and promotions! You can check our website or sign up for our newsletter to stay updated.",
        "can I track my order?": "Of course! Please provide your order number and I'll look up the status for you.",
        "how do I return an item?": "We have a hassle-free return policy. Simply contact our customer service team and they'll assist you with the return process.",
        "what payment methods do you accept?": "We accept various payment methods including credit/debit cards, PayPal, and bank transfers.",
        "do you offer international shipping?": "Yes, we offer international shipping to many countries. You can check the shipping options during checkout.",
        "how long does shipping take?": "Shipping times depend on your location and the shipping method chosen. You can find estimated delivery times during checkout.",
        "is my personal information secure?": "Absolutely! We take customer privacy and security very seriously. Your personal information is encrypted and protected.",
        "what's your refund policy?": "We offer refunds on eligible items within a specified period. Please refer to our refund policy for more details.",
        "do you have a customer loyalty program?": "Yes, we have a loyalty program where you can earn points for every purchase and redeem them for discounts or rewards.",
        "can I speak to a human representative?": "Certainly! If you need further assistance, please contact our customer service team and they'll be happy to help.",
        "bye": "Thank you for visiting our store! Have a great day!",
    }
    response = responses.get(user_input.lower(), "I'm sorry, I didn't understand that.")
    return response

if __name__ == "__main__":
    chat()
# Out:
# Hi there!
# What's your name? Suraj
# Nice to meet you, Suraj!
# You: Hey
# Bot: I'm sorry, I didn't understand that.
# You: hello
# Bot: Hello! Welcome to our online store. How can I assist you today?
# You: how do I return an item?
# Bot: I'm sorry, I didn't understand that.
# You: what products do you offer?
# Bot: We offer a wide range of products including electronics, clothing, accessories, home goods, and more!
# You: do you have any sales or promotions?
# Bot: Yes, we often have sales and promotions! You can check our website or sign up for our newsletter to stay updated.
# You: exit
# Bot: Goodbye!

# %%
import random

class TriviaBot:
    def __init__(self):
        self.questions = {
            "science": [
                {"question": "What is the chemical symbol for water?", "answer": "H2O"},
                {"question": "What planet is known as the Red Planet?", "answer": "Mars"},
                {"question": "What is the powerhouse of the cell?", "answer": "Mitochondria"}
            ],
            "history": [
                {"question": "Who was the first president of the United States?", "answer": "George Washington"},
                {"question": "In which year did World War II end?", "answer": "1945"},
                {"question": "Who wrote the Declaration of Independence?", "answer": "Thomas Jefferson"}
            ],
            "general": [
                {"question": "What is the capital of France?", "answer": "Paris"},
                {"question": "How many continents are there?", "answer": "7"},
                {"question": "What is the tallest mammal in the world?", "answer": "Giraffe"}
            ]
        }

    def greet(self):
        greetings = ["Welcome to TriviaBot! Let's test your knowledge.", "Hello! Are you ready for some trivia?"]
        return random.choice(greetings)

    def select_category(self):
        categories = list(self.questions.keys())
        return random.choice(categories)

    def ask_question(self, category):
        question = random.choice(self.questions[category])
        return question["question"], question["answer"]

    def calculate_score(self, correct_answers, total_questions):
        score = (correct_answers / total_questions) * 100
        return score

    def display_score(self, correct_answers, total_questions):
        score = self.calculate_score(correct_answers, total_questions)
        print("Your score: {:.2f}% ({} out of {})".format(score, correct_answers, total_questions))

    def chat(self):
        print(self.greet())
        correct_answers = 0
        total_questions = 0
        while True:
            category = self.select_category()
            question, answer = self.ask_question(category)
            print("Category:", category.capitalize())
            user_input = input("Question: " + question + " ")
            if user_input.lower() == 'exit':
                print("Thanks for playing TriviaBot!")
                self.display_score(correct_answers, total_questions)
                break
            total_questions += 1
            if user_input.lower() == answer.lower():
                print("Correct! Well done!")
                correct_answers += 1
            else:
                print("Incorrect. The correct answer is:", answer)
        self.display_score(correct_answers, total_questions)

if __name__ == "__main__":
    bot = TriviaBot()
    bot.chat()
# Out:
# Welcome to TriviaBot! Let's test your knowledge.
# Category: Science
# Question: What planet is known as the Red Planet? mars
# Correct! Well done!
# Category: General
# Question: What is the tallest mammal in the world? jiraffee
# Incorrect. The correct answer is: Giraffe
# Category: General
# Question: What is the capital of France? paris
# Correct! Well done!
# Category: Science
# Question: What is the powerhouse of the cell? Mitochondria
# Correct! Well done!
# Category: Science
# Question: What planet is known as the Red Planet? mars
# Correct! Well done!
# Category: Science
# Question: What planet is known as the Red Planet? mars
# Correct! Well done!
# Category: General
# Question: How many continents are there? 7
# Correct! Well done!
# Category: History
# Question: Who wrote the Declaration of Independence? Thomas Jefferson
# Correct! Well done!
# Category: Science
# Question: What is the chemical symbol for water? h2o
# Correct! Well done!
# Category: Science
# Question: What planet is known as the Red Planet? exit
# Thanks for playing TriviaBot!
# Your score: 88.89% (8 out of 9)
# Your score: 88.89% (8 out of 9)
